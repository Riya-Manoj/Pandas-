# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print(df.shape)
# Out:
# (150, 6)

# %%
print(df.dtypes)
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# Id               150
# SepalLengthCm     35
# SepalWidthCm      23
# PetalLengthCm     43
# PetalWidthCm      22
# Species            3
# dtype: int64

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
print(df['Species'].head())
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %%
print(df[['SepalLengthCm','PetalLengthCm']])
# Out:
#      SepalLengthCm  PetalLengthCm
# 0              5.1            1.4
# 1              4.9            1.4
# 2              4.7            1.3
# 3              4.6            1.5
# 4              5.0            1.4
# ..             ...            ...
# 145            6.7            5.2
# 146            6.3            5.0
# 147            6.5            5.2
# 148            6.2            5.4
# 149            5.9            5.1
#
# [150 rows x 2 columns]

# %%
df.iloc[0:5]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.loc[0:5,['Species','SepalLengthCm']]
# Out:
#        Species  SepalLengthCm
# 0  Iris-setosa            5.1
# 1  Iris-setosa            4.9
# 2  Iris-setosa            4.7
# 3  Iris-setosa            4.6
# 4  Iris-setosa            5.0
# 5  Iris-setosa            5.4

# %%
print(df[df['SepalLengthCm']>5.0])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 10    11            5.4           3.7            1.5           0.2
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 5       Iris-setosa
# 10      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# ..              ...
# ...

# %%
print(df[df['Species']=='Iris-setosa'])
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
print(df.sort_values('SepalLengthCm').head())
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 42  43            4.4           3.2            1.3           0.2  Iris-setosa
# 38  39            4.4           3.0            1.3           0.2  Iris-setosa
# 41  42            4.5           2.3            1.3           0.3  Iris-setosa

# %%
print(df.sort_values(['Species','PetalLengthCm'],ascending=[True,False]).head())
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 24  25            4.8           3.4            1.9           0.2  Iris-setosa
# 44  45            5.1           3.8            1.9           0.4  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 20  21            5.4           3.4            1.7           0.2  Iris-setosa

# %%
df['SepalRatio']=df['SepalLengthCm']/df['SepalWidthCm']
print(df.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    SepalRatio
# 0    1.457143
# 1    1.633333
# 2    1.468750
# 3    1.483871
# 4    1.388889

# %%
print(df['SepalLengthCm'].mean())
# Out:
# 5.843333333333334

# %%
print(df.groupby('Species')['SepalLengthCm'].mean())
# Out:
# Species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: SepalLengthCm, dtype: float64

# %%
print(df.groupby('Species').agg({'SepalLengthCm':'mean','PetalLengthCm':'max'}))
# Out:
#                  SepalLengthCm  PetalLengthCm
# Species
# Iris-setosa              5.006            1.9
# Iris-versicolor          5.936            5.1
# Iris-virginica           6.588            6.9

# %%
df['SepalDouble']=df['SepalLengthCm'].apply(lambda x:x*2)
print(df.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    SepalRatio  SepalDouble
# 0    1.457143         10.2
# 1    1.633333          9.8
# 2    1.468750          9.4
# 3    1.483871          9.2
# 4    1.388889         10.0

# %%
print(df['Species'].unique())
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
print(df['Species'].value_counts())
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
print(df.corr(numeric_only=True))
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
# SepalRatio     0.716402       0.728971     -0.743521       0.836602
# SepalDouble    0.716676       1.000000     -0.109369       0.871754
#
#                PetalWidthCm  SepalRatio  SepalDouble
# Id                 0.899759    0.716402     0.716676
# SepalLengthCm      0.817954    0.728971     1.000000
# SepalWidthCm      -0.356544   -0.743521    -0.109369
# PetalLengthCm      0.962757    0.836602     0.871754
# PetalWidthCm       1.000000    0.751725     0.817954
# SepalRatio         0.751725    1.000000     0.728971
# ...

# %%
df['SepalLengthCm'].plot(kind='hist',title='Sepal Length',edgecolor='black')
# Out:
# <Axes: title={'center': 'Sepal Length'}, ylabel='Frequency'>

# %%
df.groupby('Species')['PetalLengthCm'].mean().plot(kind='bar',title='Avg Petal Length')
# Out:
# <Axes: title={'center': 'Avg Petal Length'}, xlabel='Species'>
